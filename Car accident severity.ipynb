# %% [markdown]
# #  Introduction/Business Problem :

# %% [markdown]
# In the matter of emergency help for severe car accidents, quickness in response is the most important factor. Being alert in advance about the chance of happening a car accident with injuries, help medical staff to be prepared and ready. Having the data of accident with injuries and their conditions can be used to predict the chance of similar car accident in those conditions.
# By identifying the most important factors in severe car accidents we can have a better look for nearby medical staff preparation.

# %% [markdown]
# # Data:

# %% [markdown]
# Factors such as weather, road, and light conditions have a major role in causing car accidents. By identifying the type of road, weather and light conditions which under them sever accidents have happened is the first step to help medical staff. The classification of car accidents with injuries based on these conditions is the main problem then based on similar conditions in the future, nearby medical staff could have a better understanding of possible emergencies and reschedule their shifts.
# For example by knowing that in a rainy night and wet road, we have most car accidents with injuries, so the nearby hospitals should have emergency teams alert and ready.

# %%
import pandas as pd

# %%
accidents=pd.read_csv("Data-Collisions.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accidents.head(10)
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
# 5             1 -122.387598  47.690575         6  320840     322340  E919477
# 6             1 -122.338485  47.618534         7   83300      83300  3282542
# 7             2 -122.320780  47.614076         9  330897     332397  EA30304
# 8             1 -122.335930  47.611904        10   63400      63400  2071243
# 9             2 -122.384700  47.528475        12   58600      58600  2072105
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# ...

# %%
accidents['WEATHER']
# Out:
# 0         Overcast
# 1          Raining
# 2         Overcast
# 3            Clear
# 4          Raining
#             ...
# 194668       Clear
# 194669     Raining
# 194670       Clear
# 194671       Clear
# 194672       Clear
# Name: WEATHER, Length: 194673, dtype: object
